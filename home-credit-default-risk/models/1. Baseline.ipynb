# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('..//data//application_train.csv')
dataset = dataset.set_index('SK_ID_CURR')

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score
from sklearn.metrics import cohen_kappa_score

from sklearn.utils import shuffle
from sklearn.model_selection import cross_val_predict

# %%
model = LogisticRegression()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
features = imputed.drop(['TARGET'], axis=1)
labels = imputed['TARGET']

# Impute by median
features = dataset.fillna(dataset.median())

# %%
features
# Out:
#             TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# SK_ID_CURR
# 100002           1         Cash loans           M            N
# 100003           0         Cash loans           F            N
# 100004           0    Revolving loans           M            Y
# 100006           0         Cash loans           F            N
# 100007           0         Cash loans           M            N
# 100008           0         Cash loans           M            N
# 100009           0         Cash loans           F            Y
# 100010           0         Cash loans           M            Y
# 100011           0         Cash loans           F            N
# 100012           0    Revolving loans           M            N
# 100014           0         Cash loans           F            N
# 100015           0         Cash loans           F            N
# 100016           0         Cash loans           F            N
# 100017           0         Cash loans           M            Y
# ...

# %%
le = LabelEncoder()
oh = OneHotEncoder()

le.fit(features[['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN']])
le_encoded = le.transform(features)

oh.fit(le_encoded)
oh.transform(le_encoded)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-9312ca7789f2> in <module>()
#       2 oh = OneHotEncoder()
#       3
# ----> 4 le.fit(features[['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN']])
#       5 le_encoded = le.transform(features)
#       6
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py in fit(self, y)
#      93         self : returns an instance of self.
#      94         """
# ---> 95         y = column_or_1d(y, warn=True)
#      96         self.classes_ = np.unique(y)
#      97         return self
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     581         return np.ravel(y)
#     582
# --> 583     raise ValueError("bad input shape {0}".format(shape))
#     584
#     585
#
# ValueError: bad input shape (307511, 4)

# %%
oh.fit(le_encoded)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-20d5e29bec4b> in <module>()
# ----> 1 oh.fit(le_encoded)
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#    1954         self
#    1955         """
# -> 1956         self.fit_transform(X)
#    1957         return self
#    1958
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit_transform(self, X, y)
#    2017         """
#    2018         return _transform_selected(X, self._fit_transform,
# -> 2019                                    self.categorical_features, copy=True)
#    2020
#    2021     def _transform(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in _transform_selected(X, transform, selected, copy)
#    1807     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1808     """
# ...

# %%
features['CODE_GENDER']

# %%
pred = cross_val_predict(model, features, labels, method='predict_proba')

# %%
pred = cross_val_predict(model, features[:1000], labels[:1000])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-ed88fe66d488> in <module>()
#       1
# ----> 2 pred = cross_val_predict(model, features[:1000], labels[:1000])
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_predict(estimator, X, y, groups, cv, n_jobs, verbose, fit_params, pre_dispatch, method)
#     653     prediction_blocks = parallel(delayed(_fit_and_predict)(
#     654         clone(estimator), X, y, train, test, verbose, fit_params, method)
# --> 655         for train, test in cv.split(X, y, groups))
#     656
#     657     # Concatenate the predictions
#
# ~\Anaconda3\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     777             # was dispatched. In particular this covers the edge
#     778             # case of Parallel used with an exhausted iterator.
# ...

# %%
accuracy_score(pred, labels)
# Out:
# 0.91927118054313506
